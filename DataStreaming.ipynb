# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
import pyspark.sql.functions as f

# %%
spark = SparkSession.builder \
.master("local[4]") \
.appName("ReafDromCsv") \
.config("spark.driver.memory","2g") \
.config("spark.executor.memory","4g") \
.getOrCreate()

# %%
# schema tanımla
schema_simple_data = StructType(
[
    StructField("sirano", IntegerType(), True),
    StructField("isim", StringType(), True),
    StructField("yas", IntegerType(), True),
    StructField("meslek", StringType(), True),
    StructField("sehir", StringType(), True),
    StructField("aylik_gelir", DoubleType(), True)
]
)

# %%
df = spark.readStream \
.format("csv") \
.option("header",True) \
.option("sep", ",") \
.schema(schema_simple_data) \
.load("D:\\spark-streaming-test")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# C:\spark\python\pyspark\sql\utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# C:\spark\python\lib\py4j-0.10.7-src.zip\py4j\protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o60.load.
# : org.apache.spark.sql.AnalysisException: Path does not exist: D:\spark-streaming-test;
# 	at org.apache.spark.sql.execution.datasources.DataSource.sourceSchema(DataSource.scala:247)
# 	at org.apache.spark.sql.execution.datasources.DataSource.sourceInfo$lzycompute(DataSource.scala:94)
# 	at org.apache.spark.sql.execution.datasources.DataSource.sourceInfo(DataSource.scala:94)
# 	at org.apache.spark.sql.execution.streaming.StreamingRelation$.apply(StreamingRelation.scala:33)
# 	at org.apache.spark.sql.streaming.DataStreamReader.load(DataStreamReader.scala:196)
# 	at org.apache.spark.sql.streaming.DataStreamReader.load(DataStreamReader.scala:206)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-5-79780f894766> in <module>
#       4 .option("sep", ",") \
#       5 .schema(schema_simple_data) \
# ----> 6 .load("D:\\spark-streaming-test")
#
# C:\spark\python\pyspark\sql\streaming.py in load(self, path, format, schema, **options)
#     399                 raise ValueError("If the path is provided for stream, it needs to be a " +
#     400                                  "non-empty string. List of paths are not supported.")
# --> 401             return self._df(self._jreader.load(path))
#     402         else:
#     403             return self._df(self._jreader.load())
#
# C:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# C:\spark\python\pyspark\sql\utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'Path does not exist: D:\\spark-streaming-test;'

# %%
meslek_grp_ort_gelir = df.groupBy("meslek") \
.agg(f.avg("aylik_gelir").alias("ort_gelir")) \
.sort(f.desc("ort_gelir"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9a0bf241d5e4> in <module>
# ----> 1 meslek_grp_ort_gelir = df.groupBy("meslek") \
#       2 .agg(f.avg("aylik_gelir").alias("ort_gelir")) \
#       3 .sort(f.desc("ort_gelir"))
#
# NameError: name 'df' is not defined

# %%
query = meslek_grp_ort_gelir.writeStream \
.outputMode("complete") \
.format("console") \
.start()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-32b2888c3d25> in <module>
# ----> 1 query = meslek_grp_ort_gelir.writeStream \
#       2 .outputMode("complete") \
#       3 .format("console") \
#       4 .start()
#
# NameError: name 'meslek_grp_ort_gelir' is not defined

# %%
query.awaitTermination()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-885fef5a9f37> in <module>
# ----> 1 query.awaitTermination()
#
# NameError: name 'query' is not defined

# %%
query.stop()
